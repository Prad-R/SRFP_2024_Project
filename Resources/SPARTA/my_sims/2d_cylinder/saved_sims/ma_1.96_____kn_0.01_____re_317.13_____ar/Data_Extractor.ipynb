# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sim_data = pd.read_csv('data.csv', header = None)

# %%
sim_data
# Out:
#           0        1       2   3      4       5       6        7          8   \
# 0          0     0.45  504000   0      0       0  0.0000   0.0000     0.0000
# 1       5000    15.28  591509   1  56867   92141 -0.0255   0.0679    -2.6589
# 2      10000    34.08  640882   4  68349  112782  0.0875  10.2672   117.3258
# 3      15000    54.32  657986   1  65707  110035 -0.1705  10.1655   -59.6375
# 4      20000    74.94  634240   3  57152   97039  0.0749  10.8862   145.3105
# ..       ...      ...     ...  ..    ...     ...     ...      ...        ...
# 196   980000  2408.39  503590   2  35698   63280  0.0310  11.2153   361.2240
# 197   985000  2420.41  503995   0  35628   63341 -0.0679  10.7771  -158.7172
# 198   990000  2432.56  503854   1  35921   63433 -0.0020  10.7623 -5478.7760
# 199   995000  2445.15  503564   0  35849   63329  0.0695  11.3668   163.6118
# 200  1000000  2457.34  503838   2  35781   63304  0.0068  10.9580  1610.1708
#
#          9         10
# ...

# %%
dens_data = pd.read_csv('dens.csv', header = None)

# %%
dens_data
# Out:
#            0
# 0   0.001423
# 1   0.001455
# 2   0.001540
# 3   0.001434
# 4   0.001529
# 5   0.001391
# 6   0.001508
# 7   0.001498
# 8   0.001434
# 9   0.001466
# 10  0.001423
# 11  0.001519
# 12  0.001434
# 13  0.001455
# 14  0.001349
# 15  0.001444
# 16  0.001540
# 17  0.001551
# 18  0.001434
# 19  0.001551
# 20  0.001444
# 21  0.001476
# 22  0.001444
# 23  0.001381
# 24  0.001476
# 25  0.001551
# 26  0.001381
# 27  0.001540
# 28  0.001508
# 29  0.001561
# 30  0.001338
# 31  0.001508
# 32  0.001572
# 33  0.001455
# 34  0.001540
# 35  0.001455
# 36  0.001391
# 37  0.001519
# 38  0.001540
# 39  0.001583

# %%
dens = np.mean(dens_data)
print(dens)
u = 816.268
d = 0.01
# Out:
# 0.0014760765

# %%
drag = np.mean(sim_data[7][10:200])
print(drag)
lift = np.mean(sim_data[6][12:200])
print(lift)
# Out:
# 10.925864210526317
# -0.007126063829787232

# %%
cd = (2 * drag) / (dens * u ** 2 * d)
print(cd)
# Out:
# 2.2218328611602187

# %%
plt.scatter(np.log10(0.01), cd)
plt.ylim(1,4)
plt.yticks(np.arange(1,4,0.5))
plt.xlim(-5,1)
# Out:
# (-5.0, 1.0)
