# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sim_data = pd.read_csv('data.csv', header = None)

# %%
sim_data
# Out:
#           0        1       2   3      4      5       6       7       8   \
# 0          0     0.43  192000   0      0      0  0.0000  0.0000  0.0000
# 1       5000     7.41  197652   2  14009  23473 -0.1284  0.8648 -6.7369
# 2      10000    12.42  191673   9  13514  22473 -0.1356  1.0862 -8.0108
# 3      15000    17.38  191570   4  13314  22447 -0.1365  1.0773 -7.8918
# 4      20000    22.38  191329   7  13452  22536 -0.1427  1.0807 -7.5712
# ..       ...      ...     ...  ..    ...    ...     ...     ...     ...
# 196   980000   989.98  191895   3  13344  22873 -0.1404  1.0832 -7.7136
# 197   985000   995.06  192140   8  13574  22989 -0.1468  1.0925 -7.4440
# 198   990000  1000.07  191799   6  13463  22856 -0.1403  1.0809 -7.7020
# 199   995000  1005.13  191652   7  13327  22902 -0.1351  1.0856 -8.0352
# 200  1000000  1010.16  191844   7  13388  22801 -0.1380  1.0872 -7.8784
#
#          9        10
# 0    0.0800  39.6415
# 1    0.0777  40.8085
# 2    0.0801  39.5740
# 3    0.0802  39.5527
# 4    0.0803  39.5030
# ..      ...      ...
# 196  0.0800  39.6199
# 197  0.0799  39.6704
# 198  0.0801  39.6000
# 199  0.0801  39.5697
# 200  0.0801  39.6093
#
# [201 rows x 11 columns]

# %%
dens_data = pd.read_csv('dens.csv', header = None)

# %%
dens_data
# Out:
#            0
# 0   0.000105
# 1   0.000118
# 2   0.000112
# 3   0.000139
# 4   0.000139
# ..       ...
# 75  0.000230
# 76  0.000244
# 77  0.000272
# 78  0.000258
# 79  0.000265
#
# [80 rows x 1 columns]

# %%
dens = np.mean(dens_data)
print(dens)
u = 816.268
d = 0.01
# Out:
# 0.0001917658275

# %%
drag = np.mean(sim_data[7][10:200])

# %%
cd = (2 * drag) / (dens * u ** 2 * d)

# %%
plt.scatter(np.log10(0.08), cd)
plt.ylim(1,4)
plt.yticks(np.arange(1,4,0.5))
plt.xlim(-5,1)
# Out:
# (-5.0, 1.0)
